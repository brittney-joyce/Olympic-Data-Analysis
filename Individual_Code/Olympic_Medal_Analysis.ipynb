# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import time
import seaborn

# %%
#read csv
medals = "../TM Group Project/olympic_medalists.csv"
medals_df = pd.read_csv("olympicsall.csv", encoding = "ISO-8859-1")

# %%
medals_df.head()
# Out:
#    Year  Season    City     Sport Discipline             Athlete  Country  \
# 0  1896  Summer  Athens  Aquatics   Swimming       HAJOS, Alfred  Hungary
# 1  1896  Summer  Athens  Aquatics   Swimming    HERSCHMANN, Otto  Austria
# 2  1896  Summer  Athens  Aquatics   Swimming   DRIVAS, Dimitrios   Greece
# 3  1896  Summer  Athens  Aquatics   Swimming  MALOKINIS, Ioannis   Greece
# 4  1896  Summer  Athens  Aquatics   Swimming  CHASAPIS, Spiridon   Greece
#
#    Population GDP per Capita Gender                       Event   Medal
# 0   9844686.0       12363.54    Men              100M Freestyle    Gold
# 1   8611088.0       43774.99    Men              100M Freestyle  Silver
# 2  10823732.0       18002.23    Men  100M Freestyle For Sailors  Bronze
# 3  10823732.0       18002.23    Men  100M Freestyle For Sailors    Gold
# 4  10823732.0       18002.23    Men  100M Freestyle For Sailors  Silver

# %%
#countries with the most medals
country_count = medals_df[["Country", "Medal"]]
country_count.head(50)
# Out:
#            Country   Medal
# 0          Hungary    Gold
# 1          Austria  Silver
# 2           Greece  Bronze
# 3           Greece    Gold
# 4           Greece  Silver
# 5           Greece  Bronze
# 6          Hungary    Gold
# 7           Greece  Silver
# 8           Greece  Bronze
# 9          Austria    Gold
# 10          Greece  Silver
# 11   United States  Bronze
# 12         Hungary  Bronze
# 13   United States    Gold
# 14         Germany  Silver
# 15   United States    Gold
# 16  United Kingdom  Silver
# 17          France  Bronze
# 18       Australia    Gold
# 19   United States  Silver
# 20  United Kingdom  Bronze
# 21   United States    Gold
# 22   United States  Silver
# 23          Greece  Bronze
# 24       Australia    Gold
# 25         Hungary  Silver
# 26          Greece  Bronze
# 27   United States    Gold
# 28          Greece  Silver
# 29   United States    Gold
# 30   United States  Silver
# 31   United States  Silver
# 32   United States  Bronze
# ...

# %%
country_medals= pd.DataFrame(country_count[("Country")].value_counts())
country_medals.head()
# Out:
#                 Country
# United States      5238
# United Kingdom     1799
# Germany            1665
# France             1548
# Italy              1488

# %%
# Bar graph for Country Medal Count
x_axis = np.arange(len(country_medals))
tick_locations = [value+0.4 for value in x_axis]
#plt.figure(figsize=(500,1))
plt.bar(x_axis, country_medals["Country"], color='r', alpha=0.5, align="edge")
plt.xticks(tick_locations, country_medals["Country"], rotation="vertical")

plt.xlim(-0.25, 100)
plt.ylim(0, 2000)

plt.show()

# %%
#gender analysis by year 
gender_analysis = pd.DataFrame( {"Medals Count":medals_df.groupby(['Gender','Year', 'Season']).size()} ).reset_index() #.groupby(['Gender','Year']) 
men = gender_analysis[gender_analysis["Gender"] == "Men"] 
women = gender_analysis[gender_analysis["Gender"] == "Women"]

# %%
#gender analysis by year
gender_analysis = pd.DataFrame( {"Medals Count":medals_df.groupby(['Gender','Year', 'Season']).size()} ).reset_index() #.groupby(['Gender','Year'])
men = gender_analysis[gender_analysis["Gender"] == "Men"]
women = gender_analysis[gender_analysis["Gender"] == "Women"]

gender_analysis.head()
# Out:
#   Gender  Year  Season  Medals Count
# 0    Men  1896  Summer           151
# 1    Men  1900  Summer           501
# 2    Men  1904  Summer           458
# 3    Men  1908  Summer           789
# 4    Men  1912  Summer           855

# %%
## Men vs Women Scatter Plot
plt.scatter(men['Year'], men['Medals Count'], c="blue", edgecolor="black", linewidths=1, marker="o", label="Men")
plt.scatter(women['Year'], women['Medals Count'], c="pink", edgecolor="black", linewidths=1, marker="o", label = "Women")

plt.title("Medal Count By Gender")
plt.ylabel("Medal Count")
plt.xlabel("Olympic Year")
plt.xlim((1890,2020))
plt.grid(True)

plt.legend(fontsize="small", mode="Expanded", 
                  numpoints=1, scatterpoints=1, 
                  loc="upper left", title="Gender", 
                  labelspacing=0.5)

plt.show()

# %%
## Men vs Women Line Graph
menplot= plt.plot(men['Year'], men['Medals Count'], c="blue",label="Men")
womenplot= plt.plot(women['Year'], women['Medals Count'], c="pink", label = "Women")

plt.title("Medal Count By Gender")
plt.ylabel("Medal Count")
plt.xlabel("Olympic Year")
plt.xlim((1890,2020))
plt.grid(True)

plt.legend(fontsize="small", mode="Expanded", 
                  numpoints=1, scatterpoints=1, 
                  loc="upper left", title="Gender", 
                  labelspacing=0.5)

plt.show()

# %%
#season analysis by gender
gender_analysis = pd.DataFrame( {"Medals Count":medals_df.groupby(['Gender','Year', 'Season']).size()} ).reset_index() #.groupby(['Gender','Year'])
men = gender_analysis[gender_analysis["Gender"] == "Men"]
women = gender_analysis[gender_analysis["Gender"] == "Women"]
season_men= men.groupby(["Season"])
season_women=men.groupby(["Season"])
season_men.head(10)
# Out:
#    Gender  Year  Season  Medals Count
# 0     Men  1896  Summer           151
# 1     Men  1900  Summer           501
# 2     Men  1904  Summer           458
# 3     Men  1908  Summer           789
# 4     Men  1912  Summer           855
# 5     Men  1920  Summer          1255
# 6     Men  1924  Summer           833
# 7     Men  1924  Winter           112
# 8     Men  1928  Summer           615
# 9     Men  1928  Winter            83
# 10    Men  1932  Summer           555
# 11    Men  1932  Winter           110
# 12    Men  1936  Summer           791
# 13    Men  1936  Winter            99
# 15    Men  1948  Winter           125
# 17    Men  1952  Winter           118
# 19    Men  1956  Winter           123
# 21    Men  1960  Winter           108
# 23    Men  1964  Winter           139
# 25    Men  1968  Winter           153

# %%
#season analysis by gender
gender_analysis = pd.DataFrame( {"Medals Count":medals_df.groupby(['Gender','Year', 'Season']).size()} ).reset_index() #.groupby(['Gender','Year'])
men = gender_analysis[gender_analysis["Gender"] == "Men"]
women = gender_analysis[gender_analysis["Gender"] == "Women"]
season_men= men.groupby(["Season"])
season_women=women.groupby(["Season"])
season_women.head(10)
# Out:
#    Gender  Year  Season  Medals Count
# 49  Women  1900  Summer            11
# 50  Women  1904  Summer            12
# 51  Women  1908  Summer            15
# 52  Women  1912  Summer            30
# 53  Women  1920  Summer            43
# 54  Women  1924  Summer            51
# 55  Women  1924  Winter             6
# 56  Women  1928  Summer            95
# 57  Women  1928  Winter             6
# 58  Women  1932  Summer            60
# 59  Women  1932  Winter             6
# 60  Women  1936  Summer            84
# 61  Women  1936  Winter             9
# 62  Women  1948  Summer            96
# 63  Women  1948  Winter            15
# 65  Women  1952  Winter            18
# 67  Women  1956  Winter            27
# 69  Women  1960  Winter            39
# 71  Women  1964  Winter            46
# 73  Women  1968  Winter            46

# %%
winter_analysis = gender_analysis[gender_analysis["Season"] == "Winter"]
summer_analysis = gender_analysis[gender_analysis["Season"] == "Summer"]

winterplot= plt.plot(winter_analysis['Year'], winter_analysis['Medals Count'], c="blue",label="Men")
summerplot= plt.plot(summer_analysis['Year'], summer_analysis['Medals Count'], c="pink", label = "Women")

plt.title("Medal Count By Season")
plt.ylabel("Medal Count")
plt.xlabel("Olympic Year")
plt.xlim((1890,2020))
plt.grid(True)

plt.legend(fontsize="small", mode="Expanded", 
                  numpoints=1, scatterpoints=1, 
                  loc="upper left", title="Gender", 
                  labelspacing=0.5)

winter_analysis.head()
# Out:
#    Gender  Year  Season  Medals Count
# 7     Men  1924  Winter           112
# 9     Men  1928  Winter            83
# 11    Men  1932  Winter           110
# 13    Men  1936  Winter            99
# 15    Men  1948  Winter           125

# %%
#Athlete Analyis
athlete_analysis = pd.DataFrame({"Medals Count":medals_df.groupby(['Gender', 'Athlete']).size()}) #.groupby(['Gender','Year'])
men = gender_analysis[gender_analysis["Gender"] == "Men"]
women = gender_analysis[gender_analysis["Gender"] == "Women"]
athlete_analysis.sort_values(by='Medals Count', ascending=False, inplace=True)
athlete_analysis.reset_index().head()
# Out:
#   Gender             Athlete  Medals Count
# 0    Men     PHELPS, Michael            22
# 1  Women    LATYNINA, Larisa            18
# 2    Men  ANDRIANOV, Nikolay            15
# 3    Men     SHAKHLIN, Boris            13
# 4    Men        ONO, Takashi            13

# %%
#medal count per country
medal_count_analysis = medals_df.groupby(['Country','Discipline'])
medal_count = pd.DataFrame(medal_count_analysis["Medal"].count())
medal_count
# Out:
#                                      Medal
# Country         Discipline
# Afghanistan     Taekwondo                2
# Algeria         Athletics                7
#                 Boxing                   6
#                 Judo                     2
# Argentina       Athletics                5
#                 Basketball              24
#                 Boxing                  24
#                 Cycling Track            2
#                 Eventing                 1
#                 Fencing                  5
#                 Football                72
#                 Hockey                  64
#                 Judo                     1
#                 Polo                    10
#                 Rowing                   6
#                 Sailing                 20
#                 Shooting                 1
#                 Swimming                 3
#                 Taekwondo                1
#                 Tennis                   6
# ...

# %%
##US Sport Rankings
us_df = medals_df[medals_df["Country"] == "United States"]
sport_analysis = pd.DataFrame({"Medals_Count":us_df.groupby(['Country', 'Sport', 'Medal']).size()}).reset_index()
#sport_analysis.sort_values(by='Medals_Count', ascending=False, inplace=True)
#sport = medals_df.groupby(['Country','Sport'])
#sport_analysis = pd.DataFrame(sport["Medal"].count())
sport_analysis
# Out:
#           Country          Sport   Medal  Medals_Count
# 0   United States       Aquatics  Bronze           262
# 1   United States       Aquatics    Gold           578
# 2   United States       Aquatics  Silver           344
# 3   United States        Archery  Bronze            15
# 4   United States        Archery    Gold            22
# 5   United States        Archery  Silver            18
# 6   United States      Athletics  Bronze           208
# 7   United States      Athletics    Gold           491
# 8   United States      Athletics  Silver           295
# 9   United States       Baseball  Bronze            44
# 10  United States       Baseball    Gold            24
# 11  United States     Basketball  Bronze            36
# 12  United States     Basketball    Gold           258
# 13  United States     Basketball  Silver            24
# 14  United States      Bobsleigh  Bronze            33
# 15  United States      Bobsleigh    Gold            27
# ...

# %%
gold = sport_analysis[sport_analysis["Medal"] == "Gold"]
silver = sport_analysis[sport_analysis["Medal"] == "Silver"]
bronze = sport_analysis[sport_analysis["Medal"] == "Bronze"]

plt.bar(gold['Sport'], gold['Medals_Count'], color='gold', edgecolor="black", width=0.9)
plt.bar(silver["Sport"], silver['Medals_Count'], color='silver', edgecolor="black")
plt.bar(bronze['Sport'], bronze['Medals_Count'], color='darkgoldenrod', edgecolor="black")

plt.title("Top US Sports")
plt.ylabel("Medal Count")
plt.xlabel("Sport")

plt.xlim(-1, len('Sport'))
plt.ylim(1, 600)
plt.xticks(gold['Sport'], rotation="vertical")
plt.figure(figsize=(50, 10))


plt.show()
