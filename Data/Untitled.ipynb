# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
summer_df_original = pd.read_csv ("olympicsall.csv", encoding = "ISO-8859-1")
winter_df = pd.read_csv ("winter.csv", encoding = "utf-8")

# %%
summer_df_original
# summer_df.sort_values('Edition', inplace = True, ascending = True)
# summer_df
# Out:
#        Year  Season    City      Sport Discipline  \
# 0      1896  Summer  Athens   Aquatics   Swimming
# 1      1896  Summer  Athens   Aquatics   Swimming
# 2      1896  Summer  Athens   Aquatics   Swimming
# 3      1896  Summer  Athens   Aquatics   Swimming
# 4      1896  Summer  Athens   Aquatics   Swimming
# 5      1896  Summer  Athens   Aquatics   Swimming
# 6      1896  Summer  Athens   Aquatics   Swimming
# 7      1896  Summer  Athens   Aquatics   Swimming
# 8      1896  Summer  Athens   Aquatics   Swimming
# 9      1896  Summer  Athens   Aquatics   Swimming
# 10     1896  Summer  Athens   Aquatics   Swimming
# 11     1896  Summer  Athens  Athletics  Athletics
# 12     1896  Summer  Athens  Athletics  Athletics
# 13     1896  Summer  Athens  Athletics  Athletics
# 14     1896  Summer  Athens  Athletics  Athletics
# 15     1896  Summer  Athens  Athletics  Athletics
# 16     1896  Summer  Athens  Athletics  Athletics
# 17     1896  Summer  Athens  Athletics  Athletics
# ...

# %%
listYear = []
for year in summer_df_original['Year']:
    if year not in listYear:
        listYear.append(year)
        
listYear
# Out:
# [1896,
#  1900,
#  1904,
#  1908,
#  1912,
#  1920,
#  1924,
#  1928,
#  1932,
#  1936,
#  1948,
#  1952,
#  1956,
#  1960,
#  1964,
#  1968,
#  1972,
#  1976,
#  1980,
#  1984,
#  1988,
#  1992,
#  1996,
#  2000,
#  2004,
#  2008,
#  2012,
#  1994,
#  1998,
#  2002,
#  2006,
#  2010,
#  2014]
